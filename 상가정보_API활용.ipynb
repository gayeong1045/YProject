# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

saga_code = []
saga_name = []
city_name = []
hjdong = []
juso = []
lon = []
let = []

# D	소매	D03	종합소매점	D03A06	종합소매
# D	소매	D03	종합소매점	D03A01	편의점
# D	소매	D03	종합소매점	D03B10	할인점
# D	소매	D03	종합소매점	D03A02	수퍼마켓
    
open_api_key = 'oh3n93%2BmUwsTMmVjqBVN%2BJPSdFnw5%2F%2FET46RfYbH%2F4uLXLWCkAXRdI16yhhovH%2FYUP9EiHMtDoW%2FVeGzZTDvpg%3D%3D'
params = '&divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo=2'
open_url = 'http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?ServiceKey=' + open_api_key + params
res = requests.get(open_url)
soup = BeautifulSoup(res.content, 'html.parser')

data = soup.find_all('item')

for item in data :
    saga_code.append(item.select_one("bizesid").get_text())
    saga_name.append(item.select_one("bizesnm").get_text())
    city_name.append(item.select_one("ctprvnnm").get_text())
    hjdong.append(item.select_one("adongnm").get_text())
    juso.append(item.select_one("rdnm").get_text())
    # lon.append(item.select_one("lon").get_text())
    # let.append(item.select_one("let").get_text())

df = pd.DataFrame({'상가코드':saga_code,'상가이름': saga_name, '도시이름': city_name,'행정동': hjdong,'주소': juso})
df
# Out:
#          상가코드            상가이름     도시이름   행정동                  주소
# 0    11417431            열린슈퍼    광주광역시   치평동      광주광역시 서구 상무공원로
# 1    11418189           럭키슈퍼렛    서울특별시  성산2동      서울특별시 마포구 월드컵로
# 2    11418517          LG할인마트      경기도   부림동     경기도 안양시 동안구 학의로
# 3    11421325            주공수퍼     경상북도  가흥1동        경상북도 영주시 대학로
# 4    11422453  홈플러스익스프레스부산연제점    부산광역시  연산6동       부산광역시 연제구 배산로
# ..        ...             ...      ...   ...                 ...
# 195  11790413            도청슈퍼     전라남도   대덕읍  전라남도 장흥군 대덕읍 도청신월로
# 196  11790480            은정슈퍼  제주특별자치도   대륜동   제주특별자치도 서귀포시 이어도로
# 197  11790501            호남슈퍼     전라북도   입암면  전라북도 정읍시 입암면 접지중앙길
# 198  11790568            서수슈퍼     전라북도   서수면    전라북도 군산시 서수면 항쟁로
# 199  11790569            연성슈퍼     전라북도   연지동       전라북도 정읍시 연지3길
#
# [200 rows x 5 columns]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

saga_code = []
saga_name = []
city_name = []
hjdong = []
juso = []
lon = []
let = []

url_list = []

open_api_key = 'oh3n93%2BmUwsTMmVjqBVN%2BJPSdFnw5%2F%2FET46RfYbH%2F4uLXLWCkAXRdI16yhhovH%2FYUP9EiHMtDoW%2FVeGzZTDvpg%3D%3D'

for i in range(1, 11):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(11, 21):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(21, 31):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(31, 41):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(41, 51):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(51, 61):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(61, 71):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(71, 81):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(81, 91):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(91, 101):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(101, 111):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(111, 121):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(121, 131):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(131, 141):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(141, 151):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(151, 161):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(161, 171):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(171, 181):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(181, 191):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(191, 201):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(201, 211):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(211, 221):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(221, 231):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(231, 241):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
url_list = []

for i in range(241, 251):
    url_list.append('http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsSclsCd&key=D03A02&numOfRows=200&pageNo='+ str(i) + '&ServiceKey=' + open_api_key)
    
for url in url_list :
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.find_all('item')

    for item in data :
        saga_code.append(item.select_one("bizesid").get_text())
        saga_name.append(item.select_one("bizesnm").get_text())
        city_name.append(item.select_one("ctprvnnm").get_text())
        hjdong.append(item.select_one("adongnm").get_text())
        juso.append(item.select_one("rdnm").get_text())
        # lon.append(item.select_one("lon").get_text())
        # let.append(item.select_one("let").get_text())

# %%
df = pd.DataFrame({'상가코드':saga_code,'상가이름': saga_name, '도시이름': city_name,'행정동': hjdong,'주소': juso})
sel_rows = df.index[df['도시이름']=='부산광역시']
df_1 = df.loc[sel_rows]
df_1
# Out:
#            상가코드     상가이름   도시이름   행정동                   주소
# 24     10170400      킹마트  부산광역시   괘법동   부산광역시 사상구 사상로250번길
# 45     10272289     할매슈퍼  부산광역시   녹산동  부산광역시 강서구 낙동남로582번길
# 84     10544095   탑훼밀리마트  부산광역시  명지1동       부산광역시 강서구 새진목길
# 93     10614877    농축산마트  부산광역시  구포3동    부산광역시 북구 시랑로101번길
# 104    10714992     럭키마트  부산광역시  주례2동       부산광역시 사상구 백양대로
# ...         ...      ...    ...   ...                  ...
# 44115   9133925  페리호구내매점  부산광역시   중앙동        부산광역시 중구 충장대로
# 44130   9080425     초원슈퍼  부산광역시  모라3동   부산광역시 사상구 모라로192번길
# 44162   9169733     천냥마트  부산광역시  문현3동     부산광역시 남구 문현로66번길
# 44298   9177859    금곡스토아  부산광역시   금곡동         부산광역시 북구 효열로
# 44319   9429019     대성슈퍼  부산광역시  덕포2동        부산광역시 사상구 사상로
#
# [2321 rows x 5 columns]

# %%
df_1.to_csv('data/API_슈퍼마켓.csv', encoding='euc-kr')
